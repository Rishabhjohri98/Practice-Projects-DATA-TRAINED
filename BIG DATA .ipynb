# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("bigdatamart_Train.csv")

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.shape
# Out:
# (8523, 12)

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
data.skew()
# Out:
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_38944\1188251951.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.skew()
# Item_Weight                  0.082426
# Item_Visibility              1.167091
# Item_MRP                     0.127202
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# dtype: float64

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data['Item_Weight']=data['Item_Weight'].fillna(data['Item_Weight'].mean())

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.226124         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.857645         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
data['Outlet_Size'] = data['Outlet_Size'].fillna(data['Outlet_Size'].mode()[0])

# %%
data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
fig,axs=plt.subplots(1,3)
data.plot(kind='scatter',x='Item_Weight',y='Item_Outlet_Sales',ax=axs[1],figsize=(12,16))
data.plot(kind='scatter',x='Item_Visibility',y='Item_Outlet_Sales')
data.plot(kind='scatter',x='Item_MRP',y='Item_Outlet_Sales')
data.plot(kind='scatter',x='Outlet_Establishment_Year',y='Item_Outlet_Sales')
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix,roc_curve,roc_auc_score

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1

for column in data:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.countplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()
# Out:
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
from scipy.stats import zscore

# %%
z_score=zscore(data[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']])

# %%
abs_score=np.abs(z_score)
filtering_entry=(abs_score < 3).all(axis=1)

# %%
data=data[filtering_entry]

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8428.000000      8428.000000  8428.000000                8428.000000
# mean     12.861218         0.063905   140.996015                1997.911723
# std       4.238141         0.047302    62.287713                   8.356697
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.300000         0.026861    93.802150                1987.000000
# 50%      12.857645         0.053293   142.915400                1999.000000
# 75%      16.100000         0.093160   185.708200                2004.000000
# max      21.350000         0.220226   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8428.000000
# mean         2202.021401
# std          1704.631341
# min            33.290000
# 25%           862.876800
# 50%          1816.968200
# 75%          3115.944000
# max         13086.964800

# %%
plt.figure(figsize=(20,25),facecolor='red')
plotnumber=1

for column in data:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.countplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()
# Out:
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
data['Item_Identifier']=lab_enc.fit_transform(data['Item_Identifier'])
data['Item_Fat_Content']=lab_enc.fit_transform(data['Item_Fat_Content'])
data['Item_Type']=lab_enc.fit_transform(data['Item_Type'])
data['Outlet_Identifier']=lab_enc.fit_transform(data['Outlet_Identifier'])
data['Outlet_Size']=lab_enc.fit_transform(data['Outlet_Size'])
data['Outlet_Location_Type']=lab_enc.fit_transform(data['Outlet_Location_Type'])
data['Outlet_Type']=lab_enc.fit_transform(data['Outlet_Type'])
# Out:
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_38944\2449164092.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Identifier']=lab_enc.fit_transform(data['Item_Identifier'])
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_38944\2449164092.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Item_Fat_Content']=lab_enc.fit_transform(data['Item_Fat_Content'])
# C:\Users\RISHABH JOHRI\AppData\Local\Temp\ipykernel_38944\2449164092.py:3: SettingWithCopyWarning:
# ...

# %%
plt.figure(figsize=(20,25),facecolor='red')
plotnumber=1

for column in data:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()
# Out:
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from scipy.stats import zscore

# %%
z_score=zscore(data[['Item_Weight','Item_Visibility','Item_MRP','Outlet_Establishment_Year']])

# %%
abs_score=np.abs(z_score)
filtering_entry=(abs_score < 3).all(axis=1)

# %%
data=data[filtering_entry]

# %%
data.describe()
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# count      8398.000000  8398.000000       8398.000000      8398.000000
# mean        780.152060    12.863500          1.369016         0.063373
# std         449.936999     4.241487          0.644636         0.046541
# min           0.000000     4.555000          0.000000         0.000000
# 25%         395.000000     9.300000          1.000000         0.026821
# 50%         784.000000    12.857645          1.000000         0.052941
# 75%        1168.000000    16.100000          2.000000         0.092703
# max        1558.000000    21.350000          4.000000         0.205605
#
#          Item_Type     Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# count  8398.000000  8398.000000        8398.000000                8398.000000
# mean      7.230412   140.976380           4.759705                1997.936175
# std       4.206376    62.270774           2.831101                   8.352581
# ...

# %%
plt.figure(figsize=(20,25),facecolor='yellow')
plotnumber=1

for column in data:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
plt.show()
# Out:
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
corr=data.corr()

# %%
sns.heatmap(corr,annot=True,annot_kws={'size':10})
plt.show()

# %%
data=data.drop_duplicates()

# %%
data.head(n=10)
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156     9.300000                 1         0.016047          4
# 1                8     5.920000                 2         0.019278         14
# 2              662    17.500000                 1         0.016760         10
# 3             1121    19.200000                 2         0.000000          6
# 4             1297     8.930000                 1         0.000000          9
# 5              758    10.395000                 2         0.000000          0
# 6              696    13.650000                 2         0.012741         13
# 7              738    12.857645                 1         0.127470         13
# 8              440    16.200000                 2         0.016687          5
# 9              990    19.200000                 2         0.094450          5
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# ...

# %%
for column in data:
    if plotnumber<=9 :
        ax=plt.subplot(3,3,plotnumber)
    sns.boxplot(data[column])
    plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()
# Out:
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
for column in data:
    if plotnumber<=9 :
        ax=plt.subplot(3,3,plotnumber)
    sns.stripplot(data[column])
    plt.xlabel(column,fontsize=20)
    
    plotnumber+=1
plt.show()
# Out:
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\RISHABH JOHRI\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
X=data.drop(columns=['Item_Outlet_Sales'])
y=data['Item_Outlet_Sales']

# %%
scalar=StandardScaler()

# %%
X_scaled=scalar.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (8398, 11)

# %%
x_train,x_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.7,random_state=40)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg= RandomForestRegressor()

# %%
reg.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=reg.predict(x_test)

# %%
y_pred
# Out:
# array([2202.439768, 2681.5095  ,  543.55912 , ..., 2900.371276,
#        1854.712402, 1768.983994])

# %%
from sklearn.metrics import r2_score

# %%
def metric_score(reg,X_train,x_test,y_train,y_test,train=True):
    if train:
        y_pred=reg.predict(X_train)
        print("Test R2 SCORE",r2_score(y_train,y_pred))
    
     
        
        
    elif train==False:
        pred=reg.predict(x_test)
        
        print("Accuracy Score:{accuracy_score(y_test,pred)* 100}")
        print("Test R2 SCORE",r2_score(y_test,pred))

# %%
metric_score(reg,x_train,x_test,y_train,y_test,train=True)
metric_score(reg,x_train,x_test,y_train,y_test,train=False)
# Out:
# Test R2 SCORE 0.9338575394318798
# Accuracy Score:{accuracy_score(y_test,pred)* 100}
# Test R2 SCORE 0.5447152683008394

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ada=AdaBoostRegressor()

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred=ada.predict(x_train)

# %%
y_pred
# Out:
# array([1568.7847083 , 3760.38444226, 3091.31554774, ..., 1760.56265825,
#        1568.7847083 , 2072.86969418])

# %%
metric_score(ada,x_train,x_test,y_train,y_test,train=True)
metric_score(ada,x_train,x_test,y_train,y_test,train=False)
# Out:
# Test R2 SCORE 0.4681716756476305
# Accuracy Score:{accuracy_score(y_test,pred)* 100}
# Test R2 SCORE 0.4472761510578881

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
lr=LinearRegression()
dt=DecisionTreeRegressor()

# %%
lr.fit(x_train,y_train)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
metric_score(dt,x_train,x_test,y_train,y_test,train=True)
metric_score(dt,x_train,x_test,y_train,y_test,train=False)
# Out:
# Test R2 SCORE 1.0
# Accuracy Score:{accuracy_score(y_test,pred)* 100}
# Test R2 SCORE 0.15252353954004882

# %%
metric_score(lr,x_train,x_test,y_train,y_test,train=True)
metric_score(lr,x_train,x_test,y_train,y_test,train=False)
# Out:
# Test R2 SCORE 0.49980810360107364
# Accuracy Score:{accuracy_score(y_test,pred)* 100}
# Test R2 SCORE 0.507314411987799

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_param={'criterion':['squared_error','absolute_error'],'max_depth':[2,5],'min_samples_leaf':[2,10],
            'min_samples_split':[3,10],
            'max_leaf_nodes':[5,10]}

# %%
grid_search=GridSearchCV(estimator=reg,param_grid=grid_param,cv=5,n_jobs=-1)

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [2, 5], 'max_leaf_nodes': [5, 10],
#                          'min_samples_leaf': [2, 10],
#                          'min_samples_split': [3, 10]})

# %%
best_parameters=grid_search.best_params_
best_parameters
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'max_leaf_nodes': 10,
#  'min_samples_leaf': 10,
#  'min_samples_split': 3}

# %%
data.skew()
# Out:
# Item_Identifier             -0.009382
# Item_Weight                  0.089783
# Item_Fat_Content             1.012083
# Item_Visibility              0.755971
# Item_Type                    0.100244
# Item_MRP                     0.128411
# Outlet_Identifier           -0.069721
# Outlet_Establishment_Year   -0.413000
# Outlet_Size                 -0.081726
# Outlet_Location_Type        -0.214319
# Outlet_Type                  0.954006
# Item_Outlet_Sales            1.171908
# dtype: float64

# %%
data['Item_Fat_Content']=np.log(data['Item_Fat_Content'])
data['Item_Outlet_Sales']=np.log(data['Item_Outlet_Sales'])

# %%
data.skew()
# Out:
# Item_Identifier             -0.009382
# Item_Weight                  0.089783
# Item_Fat_Content                  NaN
# Item_Visibility              0.755971
# Item_Type                    0.100244
# Item_MRP                     0.128411
# Outlet_Identifier           -0.069721
# Outlet_Establishment_Year   -0.413000
# Outlet_Size                 -0.081726
# Outlet_Location_Type        -0.214319
# Outlet_Type                  0.954006
# Item_Outlet_Sales           -0.906243
# dtype: float64

# %%
import pickle

# %%
pickle.dump(reg,open('reg_model','wb'))
